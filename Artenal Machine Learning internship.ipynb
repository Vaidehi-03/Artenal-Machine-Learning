# %% [markdown]
# ## Importing the basic required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading the data

# %%
data = pd.read_csv('nba_2013.csv')

# %%
data.head()
# Out:
#           player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  ...  \
# 0     Quincy Acy  SF   23          TOT  63   0   847   66   141  0.468  ...
# 1   Steven Adams   C   20          OKC  81  20  1197   93   185  0.503  ...
# 2    Jeff Adrien  PF   27          TOT  53  12   961  143   275  0.520  ...
# 3  Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459  ...
# 4  Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546  ...
#
#    drb  trb  ast  stl  blk  tov   pf   pts     season  season_end
# 0  144  216   28   23   26   30  122   171  2013-2014        2013
# 1  190  332   43   40   57   71  203   265  2013-2014        2013
# 2  204  306   38   24   36   39  108   362  2013-2014        2013
# 3  230  262  248   35    3  146  136  1330  2013-2014        2013
# 4  183  277   40   23   46   63  187   328  2013-2014        2013
#
# [5 rows x 31 columns]

# %%
data.tail()
# Out:
#              player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  \
# 476     Tony Wroten  SG   20          PHI  72  16  1765  345   808  0.427
# 477      Nick Young  SG   28          LAL  64   9  1810  387   889  0.435
# 478  Thaddeus Young  PF   25          PHI  79  78  2718  582  1283  0.454
# 479     Cody Zeller   C   21          CHA  82   3  1416  172   404  0.426
# 480    Tyler Zeller   C   24          CLE  70   9  1049  156   290  0.538
#
#      ...  drb  trb  ast  stl  blk  tov   pf   pts     season  season_end
# 476  ...  159  228  217   78   16  204  151   939  2013-2014        2013
# 477  ...  137  166   95   46   12   95  156  1144  2013-2014        2013
# 478  ...  310  476  182  167   36  165  213  1417  2013-2014        2013
# 479  ...  235  353   92   40   41   87  170   490  2013-2014        2013
# 480  ...  179  282   36   18   38   60  137   399  2013-2014        2013
#
# [5 rows x 31 columns]

# %%
print(data.columns)
# Out:
# Index(['player', 'pos', 'age', 'bref_team_id', 'g', 'gs', 'mp', 'fg', 'fga',
#        'fg.', 'x3p', 'x3pa', 'x3p.', 'x2p', 'x2pa', 'x2p.', 'efg.', 'ft',
#        'fta', 'ft.', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf',
#        'pts', 'season', 'season_end'],
#       dtype='object')

# %%
data.shape
# Out:
# (481, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   player        481 non-null    object
#  1   pos           481 non-null    object
#  2   age           481 non-null    int64
#  3   bref_team_id  481 non-null    object
#  4   g             481 non-null    int64
#  5   gs            481 non-null    int64
#  6   mp            481 non-null    int64
#  7   fg            481 non-null    int64
#  8   fga           481 non-null    int64
#  9   fg.           479 non-null    float64
#  10  x3p           481 non-null    int64
#  11  x3pa          481 non-null    int64
#  12  x3p.          414 non-null    float64
#  13  x2p           481 non-null    int64
#  14  x2pa          481 non-null    int64
#  15  x2p.          478 non-null    float64
#  16  efg.          479 non-null    float64
#  17  ft            481 non-null    int64
# ...

# %%
data.describe()
# Out:
#               age           g          gs           mp          fg  \
# count  481.000000  481.000000  481.000000   481.000000  481.000000
# mean    26.509356   53.253638   25.571726  1237.386694  192.881497
# std      4.198265   25.322711   29.658465   897.258840  171.832793
# min     19.000000    1.000000    0.000000     1.000000    0.000000
# 25%     23.000000   32.000000    0.000000   388.000000   47.000000
# 50%     26.000000   61.000000   10.000000  1141.000000  146.000000
# 75%     29.000000   76.000000   54.000000  2016.000000  307.000000
# max     39.000000   83.000000   82.000000  3122.000000  849.000000
#
#                fga         fg.         x3p        x3pa        x3p.  ...  \
# count   481.000000  479.000000  481.000000  481.000000  414.000000  ...
# mean    424.463617    0.436436   39.613306  110.130977    0.285111  ...
# std     368.850833    0.098672   50.855639  132.751732    0.157633  ...
# min       0.000000    0.000000    0.000000    0.000000    0.000000  ...
# ...

# %% [markdown]
# ## First we'll delete the columns which are not necessary for ML model.

# %%
data.drop(columns=['player','bref_team_id'],axis=1,inplace=True)

# %%
data.head()
# Out:
#   pos  age   g  gs    mp   fg   fga    fg.  x3p  x3pa  ...  drb  trb  ast  \
# 0  SF   23  63   0   847   66   141  0.468    4    15  ...  144  216   28
# 1   C   20  81  20  1197   93   185  0.503    0     0  ...  190  332   43
# 2  PF   27  53  12   961  143   275  0.520    0     0  ...  204  306   38
# 3  SG   28  73  73  2552  464  1011  0.459  128   300  ...  230  262  248
# 4   C   25  56  30   951  136   249  0.546    0     1  ...  183  277   40
#
#    stl  blk  tov   pf   pts     season  season_end
# 0   23   26   30  122   171  2013-2014        2013
# 1   40   57   71  203   265  2013-2014        2013
# 2   24   36   39  108   362  2013-2014        2013
# 3   35    3  146  136  1330  2013-2014        2013
# 4   23   46   63  187   328  2013-2014        2013
#
# [5 rows x 29 columns]

# %%
data.shape
# Out:
# (481, 29)

# %%
data.season.value_counts()
# Out:
# 2013-2014    481
# Name: season, dtype: int64

# %%
data.season_end.value_counts()
# Out:
# 2013    481
# Name: season_end, dtype: int64

# %%
data.drop(columns=['season','season_end'],axis=1,inplace=True)

# %%
data.head()
# Out:
#   pos  age   g  gs    mp   fg   fga    fg.  x3p  x3pa  ...    ft.  orb  drb  \
# 0  SF   23  63   0   847   66   141  0.468    4    15  ...  0.660   72  144
# 1   C   20  81  20  1197   93   185  0.503    0     0  ...  0.581  142  190
# 2  PF   27  53  12   961  143   275  0.520    0     0  ...  0.639  102  204
# 3  SG   28  73  73  2552  464  1011  0.459  128   300  ...  0.815   32  230
# 4   C   25  56  30   951  136   249  0.546    0     1  ...  0.836   94  183
#
#    trb  ast  stl  blk  tov   pf   pts
# 0  216   28   23   26   30  122   171
# 1  332   43   40   57   71  203   265
# 2  306   38   24   36   39  108   362
# 3  262  248   35    3  146  136  1330
# 4  277   40   23   46   63  187   328
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Data preprocessing

# %%
data.isnull().sum()
# Out:
# pos      0
# age      0
# g        0
# gs       0
# mp       0
# fg       0
# fga      0
# fg.      2
# x3p      0
# x3pa     0
# x3p.    67
# x2p      0
# x2pa     0
# x2p.     3
# efg.     2
# ft       0
# fta      0
# ft.     20
# orb      0
# drb      0
# trb      0
# ast      0
# stl      0
# blk      0
# tov      0
# pf       0
# pts      0
# dtype: int64

# %%
# Dealing with missing values

data['fg.'] = data['fg.'].fillna(data['fg.'].mean())
data['x3p.'] = data['x3p.'].fillna(data['x3p.'].mean())
data['x2p.'] = data['x2p.'].fillna(data['x2p.'].mean()) 
data['efg.'] = data['efg.'].fillna(data['efg.'].mean())
data['ft.'] = data['ft.'].fillna(data['ft.'].mean())

# %%
data.isnull().sum()
# Out:
# pos     0
# age     0
# g       0
# gs      0
# mp      0
# fg      0
# fga     0
# fg.     0
# x3p     0
# x3pa    0
# x3p.    0
# x2p     0
# x2pa    0
# x2p.    0
# efg.    0
# ft      0
# fta     0
# ft.     0
# orb     0
# drb     0
# trb     0
# ast     0
# stl     0
# blk     0
# tov     0
# pf      0
# pts     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pos     481 non-null    object
#  1   age     481 non-null    int64
#  2   g       481 non-null    int64
#  3   gs      481 non-null    int64
#  4   mp      481 non-null    int64
#  5   fg      481 non-null    int64
#  6   fga     481 non-null    int64
#  7   fg.     481 non-null    float64
#  8   x3p     481 non-null    int64
#  9   x3pa    481 non-null    int64
#  10  x3p.    481 non-null    float64
#  11  x2p     481 non-null    int64
#  12  x2pa    481 non-null    int64
#  13  x2p.    481 non-null    float64
#  14  efg.    481 non-null    float64
#  15  ft      481 non-null    int64
#  16  fta     481 non-null    int64
#  17  ft.     481 non-null    float64
#  18  orb     481 non-null    int64
#  19  drb     481 non-null    int64
#  20  trb     481 non-null    int64
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#Categorical Data
plt.figure(figsize=(10,8))
sns.countplot(x=data['pos'])
plt.show()

# %%
sns.histplot(data['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(data['mp'])
# Out:
# <AxesSubplot:xlabel='mp', ylabel='Count'>

# %%
sns.histplot(data['fg.'])
# Out:
# <AxesSubplot:xlabel='fg.', ylabel='Count'>

# %%
sns.histplot(data['x3p.'])
# Out:
# <AxesSubplot:xlabel='x3p.', ylabel='Count'>

# %%
sns.histplot(data['x2p.'])
# Out:
# <AxesSubplot:xlabel='x2p.', ylabel='Count'>

# %%
sns.histplot(data['efg.'])
# Out:
# <AxesSubplot:xlabel='efg.', ylabel='Count'>

# %%
sns.histplot(data['pf'])
# Out:
# <AxesSubplot:xlabel='pf', ylabel='Count'>

# %%
sns.histplot(data['pts'])
# Out:
# <AxesSubplot:xlabel='pts', ylabel='Count'>

# %% [markdown]
# ## Correlation Matrix

# %%
corr = data.corr()
corr
# Out:
#            age         g        gs        mp        fg       fga       fg.  \
# age   1.000000 -0.012074  0.025163  0.007961 -0.009749 -0.018304  0.025202
# g    -0.012074  1.000000  0.610951  0.864487  0.739993  0.746963  0.319534
# gs    0.025163  0.610951  1.000000  0.860036  0.821619  0.811531  0.234312
# mp    0.007961  0.864487  0.860036  1.000000  0.931120  0.936883  0.272614
# fg   -0.009749  0.739993  0.821619  0.931120  1.000000  0.988262  0.277273
# fga  -0.018304  0.746963  0.811531  0.936883  0.988262  1.000000  0.210588
# fg.   0.025202  0.319534  0.234312  0.272614  0.277273  0.210588  1.000000
# x3p   0.050611  0.518074  0.501808  0.645056  0.597239  0.662004 -0.025478
# x3pa  0.028850  0.537011  0.515718  0.666126  0.613988  0.685535 -0.041660
# x3p.  0.013502  0.090602  0.060238  0.126887  0.103701  0.142216 -0.028919
# x2p  -0.028862  0.684729  0.785619  0.863941  0.960853  0.924781  0.332423
# ...

# %%
plt.figure(figsize=(25,20))
sns.heatmap(corr,annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Label Encoding

# %%
data.pos.value_counts()
# Out:
# SG    109
# SF     99
# PF     96
# C      90
# PG     85
# G       1
# F       1
# Name: pos, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data['pos'] = le.fit_transform(data['pos'])

# %%
data.head()
# Out:
#    pos  age   g  gs    mp   fg   fga    fg.  x3p  x3pa  ...    ft.  orb  drb  \
# 0    5   23  63   0   847   66   141  0.468    4    15  ...  0.660   72  144
# 1    0   20  81  20  1197   93   185  0.503    0     0  ...  0.581  142  190
# 2    3   27  53  12   961  143   275  0.520    0     0  ...  0.639  102  204
# 3    6   28  73  73  2552  464  1011  0.459  128   300  ...  0.815   32  230
# 4    0   25  56  30   951  136   249  0.546    0     1  ...  0.836   94  183
#
#    trb  ast  stl  blk  tov   pf   pts
# 0  216   28   23   26   30  122   171
# 1  332   43   40   57   71  203   265
# 2  306   38   24   36   39  108   362
# 3  262  248   35    3  146  136  1330
# 4  277   40   23   46   63  187   328
#
# [5 rows x 27 columns]

# %%
data.pos.value_counts()
# Out:
# 6    109
# 5     99
# 3     96
# 0     90
# 4     85
# 1      1
# 2      1
# Name: pos, dtype: int64

# %%
data.shape
# Out:
# (481, 27)

# %% [markdown]
# ## Splitting the Data

# %%
X = data[['pos','age', 'g', 'gs', 'mp', 'fg', 'fga', 'fg.', 'x3p', 'x3pa', 'x3p.', 'x2p', 'x2pa', 'x2p.', 'efg.', 'ft', 'fta', 'ft.', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf']]
y = data['pts']

# %%
X.head()
# Out:
#    pos  age   g  gs    mp   fg   fga    fg.  x3p  x3pa  ...  fta    ft.  orb  \
# 0    5   23  63   0   847   66   141  0.468    4    15  ...   53  0.660   72
# 1    0   20  81  20  1197   93   185  0.503    0     0  ...  136  0.581  142
# 2    3   27  53  12   961  143   275  0.520    0     0  ...  119  0.639  102
# 3    6   28  73  73  2552  464  1011  0.459  128   300  ...  336  0.815   32
# 4    0   25  56  30   951  136   249  0.546    0     1  ...   67  0.836   94
#
#    drb  trb  ast  stl  blk  tov   pf
# 0  144  216   28   23   26   30  122
# 1  190  332   43   40   57   71  203
# 2  204  306   38   24   36   39  108
# 3  230  262  248   35    3  146  136
# 4  183  277   40   23   46   63  187
#
# [5 rows x 26 columns]

# %%
X.shape
# Out:
# (481, 26)

# %%
y.head()
# Out:
# 0     171
# 1     265
# 2     362
# 3    1330
# 4     328
# Name: pts, dtype: int64

# %%
y.head()
# Out:
# 0     171
# 1     265
# 2     362
# 3    1330
# 4     328
# Name: pts, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (384, 26) (384,) (97, 26) (97,)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X_scaler = MinMaxScaler()

# %%
X_train = X_scaler.fit_transform(X_train)
X_test = X_scaler.transform(X_test)

# %%
print(X_train)
# Out:
# [[0.         0.5        0.97560976 ... 0.55251142 0.42711864 0.74169742]
#  [0.5        0.25       0.7804878  ... 0.15068493 0.14915254 0.46494465]
#  [0.5        0.2        0.84146341 ... 0.52968037 0.38644068 0.68265683]
#  ...
#  [1.         0.15       0.93902439 ... 0.06392694 0.50508475 0.70110701]
#  [0.5        0.3        0.25609756 ... 0.03196347 0.06779661 0.17343173]
#  [1.         0.         0.62195122 ... 0.05022831 0.14915254 0.16605166]]

# %%
print(X_test)
# Out:
# [[1.         0.4        0.90243902 ... 0.05022831 0.14237288 0.26568266]
#  [0.66666667 0.2        0.31707317 ... 0.         0.09152542 0.12177122]
#  [0.5        0.15       0.47560976 ... 0.0456621  0.06440678 0.27306273]
#  ...
#  [0.66666667 0.25       0.6097561  ... 0.00456621 0.11525424 0.1697417 ]
#  [0.83333333 0.25       0.98780488 ... 0.08219178 0.3220339  0.57933579]
#  [0.66666667 0.2        0.01219512 ... 0.         0.         0.        ]]

# %%
y_scaler = MinMaxScaler()

# %%
y_train_reshaped = np.array(y_train).reshape(-1, 1)
y_test_reshaped = np.array(y_test).reshape(-1, 1)

# %%
y_train = y_scaler.fit_transform(y_train_reshaped)
y_test = y_scaler.transform(y_test_reshaped)

# %%
print(y_train)
# Out:
# [[4.11878133e-01]
#  [1.16853066e-01]
#  [3.00424219e-01]
#  [4.81681450e-01]
#  [1.27265715e-02]
#  [4.22676437e-01]
#  [1.00269958e-02]
#  [8.21442345e-02]
#  [1.15696105e-03]
#  [4.12649441e-02]
#  [4.24219051e-03]
#  [6.55611261e-02]
#  [7.28885461e-02]
#  [4.13035094e-01]
#  [4.16891631e-01]
#  [1.26880062e-01]
#  [7.75163903e-02]
#  [3.20092557e-02]
#  [2.50674894e-02]
#  [2.95796375e-01]
#  [5.00192827e-01]
#  [1.69687621e-02]
#  [3.02352487e-01]
#  [2.89240262e-02]
#  [4.87466255e-01]
#  [3.74084073e-02]
#  [2.08252989e-02]
#  [4.31160818e-01]
#  [2.42961820e-01]
#  [4.37331277e-01]
#  [1.57346703e-01]
#  [4.43501735e-02]
#  [4.11878133e-01]
#  [4.36174315e-01]
#  [5.29116853e-01]
#  [2.54531431e-01]
#  [3.81025839e-01]
#  [2.20593907e-01]
#  [3.31662167e-02]
#  [8.14500578e-01]
#  [0.00000000e+00]
#  [5.43771693e-02]
#  [2.69957578e-03]
#  [6.86463556e-02]
#  [6.82607019e-02]
#  [2.31392210e-03]
#  [1.05283455e-01]
#  [6.13189356e-02]
#  [5.78480524e-03]
#  [5.78480524e-02]
# ...

# %%
print(y_test)
# Out:
# [[5.32202083e-02]
#  [4.12649441e-02]
#  [2.89240262e-02]
#  [1.07983031e-02]
#  [1.59660625e-01]
#  [4.12263787e-01]
#  [1.30350945e-01]
#  [1.93983803e-01]
#  [5.55341304e-02]
#  [4.80138835e-01]
#  [5.55341304e-02]
#  [9.64134207e-02]
#  [1.69687621e-02]
#  [4.31546471e-01]
#  [5.39915156e-03]
#  [4.22290783e-01]
#  [1.04126494e-02]
#  [7.36598535e-02]
#  [6.98033166e-02]
#  [1.07983031e-02]
#  [1.65831084e-01]
#  [4.01079830e-02]
#  [4.26918627e-01]
#  [2.26764366e-01]
#  [1.34978789e-01]
#  [7.71307366e-04]
#  [4.20362514e-02]
#  [3.23949094e-02]
#  [5.61897416e-01]
#  [8.02159661e-02]
#  [2.10566911e-01]
#  [3.50173544e-01]
#  [2.68414963e-01]
#  [6.67180872e-02]
#  [2.39105283e-02]
#  [6.13189356e-02]
#  [6.69109140e-01]
#  [2.46818357e-02]
#  [5.90050135e-02]
#  [3.77940609e-02]
#  [3.20478211e-01]
#  [2.93482453e-01]
#  [4.26532973e-01]
#  [2.14037794e-01]
#  [3.81797146e-02]
#  [8.67720787e-02]
#  [1.34978789e-01]
#  [1.90898573e-01]
#  [3.88353259e-01]
#  [2.84612418e-01]
# ...

# %% [markdown]
# ### Create the KNN model, we will use regressor because we are predicting on continous values which is pts.

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn import metrics

# check for increasing neighbour values to see which has the highest regression score

for k in range(10):
    k_value = k + 1
    knn = KNeighborsRegressor(n_neighbors = k_value)
    knn.fit(X_train, y_train) 
    y_pred = knn.predict(X_test)
    print ("Regression score is:",format(metrics.r2_score(y_test, y_pred),'.4f'), "for k_value:", k_value)
# Out:
# Regression score is: 0.9358 for k_value: 1
# Regression score is: 0.9606 for k_value: 2
# Regression score is: 0.9614 for k_value: 3
# Regression score is: 0.9679 for k_value: 4
# Regression score is: 0.9693 for k_value: 5
# Regression score is: 0.9681 for k_value: 6
# Regression score is: 0.9660 for k_value: 7
# Regression score is: 0.9686 for k_value: 8
# Regression score is: 0.9678 for k_value: 9
# Regression score is: 0.9678 for k_value: 10

# %%
## Regression score is: 0.9693 for k_value: 5
## This is the higest accuracy we get

# %% [markdown]
# ### K=5, as it gives us the highest prediction score.

# %% [markdown]
# ## Creating and training the model.

# %%
knn = KNeighborsRegressor(n_neighbors = 5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# ### Making predictions on test data

# %%
y_pred = knn.predict(X_test)

# %%
y_pred
# Out:
# array([[0.10528346],
#        [0.03116082],
#        [0.06995758],
#        [0.01156961],
#        [0.12950251],
#        [0.33158504],
#        [0.13320478],
#        [0.18750482],
#        [0.09178558],
#        [0.46031624],
#        [0.07412264],
#        [0.07813344],
#        [0.02005399],
#        [0.43609718],
#        [0.01519476],
#        [0.41758581],
#        [0.0080216 ],
#        [0.06232164],
#        [0.04681836],
#        [0.01712302],
#        [0.20632472],
#        [0.05260316],
#        [0.43625145],
#        [0.26031624],
#        [0.15163903],
#        [0.01288083],
#        [0.03532588],
#        [0.04288469],
#        [0.47342846],
#        [0.03833398],
#        [0.20593907],
#        [0.34631701],
#        [0.24373313],
#        [0.08970305],
#        [0.02105669],
#        [0.05052063],
#        [0.56529117],
#        [0.02514462],
#        [0.05129194],
#        [0.04589279],
#        [0.3267258 ],
#        [0.28476668],
#        [0.467258  ],
# ...

# %% [markdown]
# ### Evaluating our Model.

# %%
print ("Mean Squared Error is:", format(metrics.mean_squared_error(y_test, y_pred), '.7f'))
print ("Regression score is:", format(metrics.r2_score(y_test, y_pred),'.4f'))
# Out:
# Mean Squared Error is: 0.0008924
# Regression score is: 0.9693

# %%
Test_With_Predicted = pd.DataFrame({'Actual Points': y_test.tolist(), 'Predicted Points': y_pred.tolist()})

Test_With_Predicted
# Out:
#               Actual Points        Predicted Points
# 0    [0.053220208252988815]    [0.1052834554569996]
# 1    [0.041264944080215964]  [0.031160817585807944]
# 2    [0.028924026224450443]    [0.0699575780948708]
# 3    [0.010798303123794832]   [0.01156961048978018]
# 4     [0.15966062475896645]   [0.12950250674893943]
# ..                      ...                     ...
# 92      [0.499421519475511]   [0.45113767836482843]
# 93  [0.0019282684149633628]  [0.012418048592364056]
# 94    [0.05399151561897416]  [0.062475896644812956]
# 95    [0.30698033166216737]    [0.2858465098341689]
# 96  [0.0011569610489780178]   [0.00902429618202854]
#
# [97 rows x 2 columns]

# %% [markdown]
# ## Building a Predictive System

# %% [markdown]
# **Label encoding of pos column : SG - 6, SF - 5, PF - 3, C - 0, PG - 4, G - 1, F - 2**

# %% [markdown]
# **Give Data in the Format of the columns we have and replace the above values by their Label Encoding**

# %% [markdown]
# **This Cell will print the actual number of points that the player might score according to the prediction of our Model.**

# %%
input_data = (3,28,82,73,2266,352,725,0.486,2,6,0.333333333333333,350,719,0.486787204450626,0.487,205,239,0.858,161,309,470,87,36,71,102,190)

input_data_array = np.asarray(input_data)

input_data_reshaped = input_data_array.reshape(1,-1)

input_data_transformed = X_scaler.transform(input_data_reshaped)

# print(input_data_transformed)

prediction = knn.predict(input_data_transformed)

print(prediction)

actual_points_pred = y_scaler.inverse_transform(prediction)

# print(actual_points_pred)

print("Prediction of points this player will score : ",actual_points_pred[0][0])
# Out:
# [[0.33436174]]
# Prediction of points this player will score :  867.0000000000001

# %% [markdown]
# ### So our Model predicts 867 pts and according to the dataset it was 911 so the model is doing a good prediction.
